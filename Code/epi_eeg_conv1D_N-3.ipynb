# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from __future__ import print_function
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
# https://github.com/AkshayRaman/EEG-Classification/

import datetime
import os
import random as rn
import json
import subprocess
import sys

import tensorflow as tf
import h5py
import numpy as np

import scipy
from keras import backend as K
from keras.layers import Activation, LSTM, GRU, Dense, Conv1D,\
        MaxPooling1D, GlobalAveragePooling1D, Dropout, Flatten,\
        SimpleRNN, PReLU, BatchNormalization, Conv2D,\
        Conv2DTranspose, MaxPooling2D, GaussianNoise
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
import keras.regularizers as regularizers
from keras.optimizers import Adam, Nadam, SGD
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping, TerminateOnNaN,\
        ReduceLROnPlateau, CSVLogger, ModelCheckpoint
from keras.utils import plot_model

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %%
import os
import pandas as pd
import numpy as np
import sys
from tqdm import tqdm
import glob

row = 3
def prep_data(path):
  data = []
  labels = []
  filenames = [img for img in glob.glob(path)]
  for name in tqdm(filenames):
      df = pd.read_csv(name, header=None, error_bad_lines=False)
      # values = df.values[row - 1]
      values = df.values
      val = sequence.pad_sequences(values, maxlen=30000)
      data.append(val.tolist())
      split = name.split(os.sep)[-2]
      if split == 'control':
        labels.append(0)
      else:
        labels.append(1)

  data = np.asarray(data)
  labels = np.asarray(labels)
  return data,labels

# %%
train_x, train_y = prep_data('/content/drive/My Drive/datasets/N_dataset/train/*/*')
# Out:
# 100%|██████████| 143/143 [06:38<00:00,  2.78s/it]

# %%
val_x, val_y = prep_data('/content/drive/My Drive/datasets/N_dataset/val/*/*')
# Out:
# 100%|██████████| 55/55 [02:29<00:00,  2.72s/it]

# %%
test_x, test_y = prep_data('/content/drive/My Drive/datasets/N_dataset/test/*/*')
# Out:
# 100%|██████████| 23/23 [01:00<00:00,  2.64s/it]

# %%
# save numpy array as npy file
from numpy import asarray
from numpy import save

# save to npy file
save('/content/drive/My Drive/saveModels/arrays/N_train_x.npy', train_x)
save('/content/drive/My Drive/saveModels/arrays/N_train_y.npy', train_y)
save('/content/drive/My Drive/saveModels/arrays/N_val_x.npy', val_x)
save('/content/drive/My Drive/saveModels/arrays/N_val_y.npy', val_y)
save('/content/drive/My Drive/saveModels/arrays/N_test_x.npy', test_x)
save('/content/drive/My Drive/saveModels/arrays/N_test_y.npy', test_y)

# %%
# from numpy import load
# train_x = load('/content/drive/My Drive/saveModels/arrays/N_train_x.npy')
# train_y = load('/content/drive/My Drive/saveModels/arrays/N_train_y.npy')
# val_x = load('/content/drive/My Drive/saveModels/arrays/N_val_x.npy')
# val_y = load('/content/drive/My Drive/saveModels/arrays/N_val_y.npy')
# test_x = load('/content/drive/My Drive/saveModels/arrays/N_test_x.npy')
# test_y = load('/content/drive/My Drive/saveModels/arrays/N_test_y.npy')

# %%
from keras.utils import to_categorical
train_Y = to_categorical(train_y)
val_Y = to_categorical(val_y)
test_Y = to_categorical(test_y)

# %%
dim1 = train_x.shape[1]
dim2 = train_x.shape[2]
filter = 10
model = Sequential()

model.add(Conv1D(filter, 3, activation='relu', input_shape=(dim1, dim2)))
model.add(MaxPooling1D(3))

model.add(LSTM(filter, activation='relu', return_sequences=True))
model.add(LSTM(filter, activation='relu', return_sequences=True))
# model.add(GaussianNoise(stddev=0.5))
model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(2, activation='softmax'))

# opt = Adam(lr=0.0011, decay=0.001)
opt = Adam()
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# %%
slug = 'muli_july_14_GB'
epoch = 500
batch_size = 16

pathModelSave = '/content/drive/My Drive/saveModels/epi_eeg_conv1D'+'_nigiria_'+'_'+str(batch_size)+'_'+str(epoch)+'_'+slug+'_.hdf5'
pathToSaveCSV = '/content/drive/My Drive/saveModels/csv/epi_eeg_conv1D'+'_nigiria_'+'_'+str(batch_size)+'_'+str(epoch)+'_'+slug+'_.csv'

# %%
#Set callbacks...
import time
_patience = min(30, max(epoch//5, 20))
# early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=_patience, verbose=1, mode='auto')

# reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, min_lr=1e-7, verbose=1)
csv_logger = CSVLogger(pathToSaveCSV, append=False, separator=',')
checkpoint = ModelCheckpoint(pathModelSave, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
callback_fns = [csv_logger, checkpoint]

tic = time.clock()
history = model.fit(
    train_x, train_Y, 
    batch_size=batch_size, 
    epochs = epoch, 
    shuffle = False,
    validation_data = (val_x, val_Y), 
    verbose = 1, 
    callbacks = callback_fns)
toc = time.clock()
# Out:
# Train on 143 samples, validate on 55 samples
# Epoch 1/500
# 143/143 [==============================] - 9s 62ms/step - loss: 6.9086 - accuracy: 0.4790 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00001: val_accuracy improved from -inf to 0.41818, saving model to /content/drive/My Drive/saveModels/epi_eeg_conv1D_nigiria__16_500_muli_july_14_GB_.hdf5
# Epoch 2/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.3052 - accuracy: 0.5734 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00002: val_accuracy did not improve from 0.41818
# Epoch 3/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1903 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00003: val_accuracy did not improve from 0.41818
# Epoch 4/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7697 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00004: val_accuracy did not improve from 0.41818
# Epoch 5/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1190 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00005: val_accuracy did not improve from 0.41818
# Epoch 6/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3857 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00006: val_accuracy did not improve from 0.41818
# Epoch 7/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0388 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00007: val_accuracy did not improve from 0.41818
# Epoch 8/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.4131 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00008: val_accuracy did not improve from 0.41818
# Epoch 9/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7454 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00009: val_accuracy did not improve from 0.41818
# Epoch 10/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0072 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00010: val_accuracy did not improve from 0.41818
# Epoch 11/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2785 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00011: val_accuracy did not improve from 0.41818
# Epoch 12/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2814 - accuracy: 0.5594 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00012: val_accuracy did not improve from 0.41818
# Epoch 13/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5255 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00013: val_accuracy did not improve from 0.41818
# Epoch 14/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3761 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00014: val_accuracy did not improve from 0.41818
# Epoch 15/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7279 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00015: val_accuracy did not improve from 0.41818
# Epoch 16/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1756 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00016: val_accuracy did not improve from 0.41818
# Epoch 17/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7503 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00017: val_accuracy did not improve from 0.41818
# Epoch 18/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8991 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00018: val_accuracy did not improve from 0.41818
# Epoch 19/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7306 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00019: val_accuracy did not improve from 0.41818
# Epoch 20/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4690 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00020: val_accuracy did not improve from 0.41818
# Epoch 21/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5768 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00021: val_accuracy did not improve from 0.41818
# Epoch 22/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8289 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00022: val_accuracy did not improve from 0.41818
# Epoch 23/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1235 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00023: val_accuracy did not improve from 0.41818
# Epoch 24/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6892 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00024: val_accuracy did not improve from 0.41818
# Epoch 25/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.5545 - accuracy: 0.4056 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00025: val_accuracy did not improve from 0.41818
# Epoch 26/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1612 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00026: val_accuracy did not improve from 0.41818
# Epoch 27/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0213 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00027: val_accuracy did not improve from 0.41818
# Epoch 28/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7603 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00028: val_accuracy did not improve from 0.41818
# Epoch 29/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6331 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00029: val_accuracy did not improve from 0.41818
# Epoch 30/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.1288 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00030: val_accuracy did not improve from 0.41818
# Epoch 31/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4007 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00031: val_accuracy did not improve from 0.41818
# Epoch 32/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0118 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00032: val_accuracy did not improve from 0.41818
# Epoch 33/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.4175 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00033: val_accuracy did not improve from 0.41818
# Epoch 34/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3856 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00034: val_accuracy did not improve from 0.41818
# Epoch 35/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.1096 - accuracy: 0.5594 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00035: val_accuracy did not improve from 0.41818
# Epoch 36/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1752 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00036: val_accuracy did not improve from 0.41818
# Epoch 37/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8947 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00037: val_accuracy did not improve from 0.41818
# Epoch 38/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9138 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00038: val_accuracy did not improve from 0.41818
# Epoch 39/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8581 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00039: val_accuracy did not improve from 0.41818
# Epoch 40/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9947 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00040: val_accuracy did not improve from 0.41818
# Epoch 41/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3663 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00041: val_accuracy did not improve from 0.41818
# Epoch 42/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2042 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00042: val_accuracy did not improve from 0.41818
# Epoch 43/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9456 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00043: val_accuracy did not improve from 0.41818
# Epoch 44/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1510 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00044: val_accuracy did not improve from 0.41818
# Epoch 45/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0398 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00045: val_accuracy did not improve from 0.41818
# Epoch 46/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.3443 - accuracy: 0.4126 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00046: val_accuracy did not improve from 0.41818
# Epoch 47/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.4127 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00047: val_accuracy did not improve from 0.41818
# Epoch 48/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0943 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00048: val_accuracy did not improve from 0.41818
# Epoch 49/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9333 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00049: val_accuracy did not improve from 0.41818
# Epoch 50/500
# 143/143 [==============================] - 1s 4ms/step - loss: 5.4445 - accuracy: 0.6154 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00050: val_accuracy did not improve from 0.41818
# Epoch 51/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2670 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00051: val_accuracy did not improve from 0.41818
# Epoch 52/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2972 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00052: val_accuracy did not improve from 0.41818
# Epoch 53/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9554 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00053: val_accuracy did not improve from 0.41818
# Epoch 54/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0487 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00054: val_accuracy did not improve from 0.41818
# Epoch 55/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.6650 - accuracy: 0.4196 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00055: val_accuracy did not improve from 0.41818
# Epoch 56/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1650 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00056: val_accuracy did not improve from 0.41818
# Epoch 57/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8125 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00057: val_accuracy did not improve from 0.41818
# Epoch 58/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3759 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00058: val_accuracy did not improve from 0.41818
# Epoch 59/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7731 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00059: val_accuracy did not improve from 0.41818
# Epoch 60/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2741 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00060: val_accuracy did not improve from 0.41818
# Epoch 61/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9859 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00061: val_accuracy did not improve from 0.41818
# Epoch 62/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1373 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00062: val_accuracy did not improve from 0.41818
# Epoch 63/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.5441 - accuracy: 0.4196 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00063: val_accuracy did not improve from 0.41818
# Epoch 64/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7919 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00064: val_accuracy did not improve from 0.41818
# Epoch 65/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.7546 - accuracy: 0.4056 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00065: val_accuracy did not improve from 0.41818
# Epoch 66/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1610 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00066: val_accuracy did not improve from 0.41818
# Epoch 67/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0264 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00067: val_accuracy did not improve from 0.41818
# Epoch 68/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.3100 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00068: val_accuracy did not improve from 0.41818
# Epoch 69/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.2498 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00069: val_accuracy did not improve from 0.41818
# Epoch 70/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7044 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00070: val_accuracy did not improve from 0.41818
# Epoch 71/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5756 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00071: val_accuracy did not improve from 0.41818
# Epoch 72/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.9815 - accuracy: 0.3636 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00072: val_accuracy did not improve from 0.41818
# Epoch 73/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7319 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00073: val_accuracy did not improve from 0.41818
# Epoch 74/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6928 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00074: val_accuracy did not improve from 0.41818
# Epoch 75/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9323 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00075: val_accuracy did not improve from 0.41818
# Epoch 76/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2959 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00076: val_accuracy did not improve from 0.41818
# Epoch 77/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8319 - accuracy: 0.4196 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00077: val_accuracy did not improve from 0.41818
# Epoch 78/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8015 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00078: val_accuracy did not improve from 0.41818
# Epoch 79/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.1987 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00079: val_accuracy did not improve from 0.41818
# Epoch 80/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3759 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00080: val_accuracy did not improve from 0.41818
# Epoch 81/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7084 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00081: val_accuracy did not improve from 0.41818
# Epoch 82/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8383 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00082: val_accuracy did not improve from 0.41818
# Epoch 83/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4791 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00083: val_accuracy did not improve from 0.41818
# Epoch 84/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0075 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00084: val_accuracy did not improve from 0.41818
# Epoch 85/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7227 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00085: val_accuracy did not improve from 0.41818
# Epoch 86/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1557 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00086: val_accuracy did not improve from 0.41818
# Epoch 87/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0493 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00087: val_accuracy did not improve from 0.41818
# Epoch 88/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2246 - accuracy: 0.5664 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00088: val_accuracy did not improve from 0.41818
# Epoch 89/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0706 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00089: val_accuracy did not improve from 0.41818
# Epoch 90/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3839 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00090: val_accuracy did not improve from 0.41818
# Epoch 91/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5368 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00091: val_accuracy did not improve from 0.41818
# Epoch 92/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4728 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00092: val_accuracy did not improve from 0.41818
# Epoch 93/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2623 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00093: val_accuracy did not improve from 0.41818
# Epoch 94/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1199 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00094: val_accuracy did not improve from 0.41818
# Epoch 95/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6241 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00095: val_accuracy did not improve from 0.41818
# Epoch 96/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9963 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00096: val_accuracy did not improve from 0.41818
# Epoch 97/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5911 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00097: val_accuracy did not improve from 0.41818
# Epoch 98/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2898 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00098: val_accuracy did not improve from 0.41818
# Epoch 99/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0212 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00099: val_accuracy did not improve from 0.41818
# Epoch 100/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1508 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00100: val_accuracy did not improve from 0.41818
# Epoch 101/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7282 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00101: val_accuracy did not improve from 0.41818
# Epoch 102/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8164 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00102: val_accuracy did not improve from 0.41818
# Epoch 103/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5708 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00103: val_accuracy did not improve from 0.41818
# Epoch 104/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3650 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00104: val_accuracy did not improve from 0.41818
# Epoch 105/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5917 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00105: val_accuracy did not improve from 0.41818
# Epoch 106/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1905 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00106: val_accuracy did not improve from 0.41818
# Epoch 107/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7006 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00107: val_accuracy did not improve from 0.41818
# Epoch 108/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1019 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00108: val_accuracy did not improve from 0.41818
# Epoch 109/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.3145 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00109: val_accuracy did not improve from 0.41818
# Epoch 110/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6180 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00110: val_accuracy did not improve from 0.41818
# Epoch 111/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3917 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00111: val_accuracy did not improve from 0.41818
# Epoch 112/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2100 - accuracy: 0.5664 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00112: val_accuracy did not improve from 0.41818
# Epoch 113/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.4273 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00113: val_accuracy did not improve from 0.41818
# Epoch 114/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7563 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00114: val_accuracy did not improve from 0.41818
# Epoch 115/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7449 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00115: val_accuracy did not improve from 0.41818
# Epoch 116/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2903 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00116: val_accuracy did not improve from 0.41818
# Epoch 117/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7396 - accuracy: 0.5245 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00117: val_accuracy did not improve from 0.41818
# Epoch 118/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3564 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00118: val_accuracy did not improve from 0.41818
# Epoch 119/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1558 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00119: val_accuracy did not improve from 0.41818
# Epoch 120/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6782 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00120: val_accuracy did not improve from 0.41818
# Epoch 121/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6970 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00121: val_accuracy did not improve from 0.41818
# Epoch 122/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7359 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00122: val_accuracy did not improve from 0.41818
# Epoch 123/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0338 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00123: val_accuracy did not improve from 0.41818
# Epoch 124/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1244 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00124: val_accuracy did not improve from 0.41818
# Epoch 125/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7475 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00125: val_accuracy did not improve from 0.41818
# Epoch 126/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9153 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00126: val_accuracy did not improve from 0.41818
# Epoch 127/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0426 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00127: val_accuracy did not improve from 0.41818
# Epoch 128/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.4258 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00128: val_accuracy did not improve from 0.41818
# Epoch 129/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1520 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00129: val_accuracy did not improve from 0.41818
# Epoch 130/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8096 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00130: val_accuracy did not improve from 0.41818
# Epoch 131/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3522 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00131: val_accuracy did not improve from 0.41818
# Epoch 132/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1758 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00132: val_accuracy did not improve from 0.41818
# Epoch 133/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9021 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00133: val_accuracy did not improve from 0.41818
# Epoch 134/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0676 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00134: val_accuracy did not improve from 0.41818
# Epoch 135/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2179 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00135: val_accuracy did not improve from 0.41818
# Epoch 136/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8230 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00136: val_accuracy did not improve from 0.41818
# Epoch 137/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5679 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00137: val_accuracy did not improve from 0.41818
# Epoch 138/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2801 - accuracy: 0.5734 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00138: val_accuracy did not improve from 0.41818
# Epoch 139/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8941 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00139: val_accuracy did not improve from 0.41818
# Epoch 140/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7041 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00140: val_accuracy did not improve from 0.41818
# Epoch 141/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.3192 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00141: val_accuracy did not improve from 0.41818
# Epoch 142/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5706 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00142: val_accuracy did not improve from 0.41818
# Epoch 143/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.2735 - accuracy: 0.3776 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00143: val_accuracy did not improve from 0.41818
# Epoch 144/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8295 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00144: val_accuracy did not improve from 0.41818
# Epoch 145/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6321 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00145: val_accuracy did not improve from 0.41818
# Epoch 146/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9278 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00146: val_accuracy did not improve from 0.41818
# Epoch 147/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4021 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00147: val_accuracy did not improve from 0.41818
# Epoch 148/500
# 143/143 [==============================] - 1s 4ms/step - loss: 5.8952 - accuracy: 0.5594 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00148: val_accuracy did not improve from 0.41818
# Epoch 149/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0301 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00149: val_accuracy did not improve from 0.41818
# Epoch 150/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1519 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00150: val_accuracy did not improve from 0.41818
# Epoch 151/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8107 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00151: val_accuracy did not improve from 0.41818
# Epoch 152/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3746 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00152: val_accuracy did not improve from 0.41818
# Epoch 153/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1916 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00153: val_accuracy did not improve from 0.41818
# Epoch 154/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8763 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00154: val_accuracy did not improve from 0.41818
# Epoch 155/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9248 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00155: val_accuracy did not improve from 0.41818
# Epoch 156/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7239 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00156: val_accuracy did not improve from 0.41818
# Epoch 157/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0571 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00157: val_accuracy did not improve from 0.41818
# Epoch 158/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5179 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00158: val_accuracy did not improve from 0.41818
# Epoch 159/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1608 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00159: val_accuracy did not improve from 0.41818
# Epoch 160/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1504 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00160: val_accuracy did not improve from 0.41818
# Epoch 161/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.4410 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00161: val_accuracy did not improve from 0.41818
# Epoch 162/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6410 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00162: val_accuracy did not improve from 0.41818
# Epoch 163/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3769 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00163: val_accuracy did not improve from 0.41818
# Epoch 164/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.3235 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00164: val_accuracy did not improve from 0.41818
# Epoch 165/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5181 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00165: val_accuracy did not improve from 0.41818
# Epoch 166/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8275 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00166: val_accuracy did not improve from 0.41818
# Epoch 167/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9944 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00167: val_accuracy did not improve from 0.41818
# Epoch 168/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5865 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00168: val_accuracy did not improve from 0.41818
# Epoch 169/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2435 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00169: val_accuracy did not improve from 0.41818
# Epoch 170/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9501 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00170: val_accuracy did not improve from 0.41818
# Epoch 171/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9081 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00171: val_accuracy did not improve from 0.41818
# Epoch 172/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2436 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00172: val_accuracy did not improve from 0.41818
# Epoch 173/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1957 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00173: val_accuracy did not improve from 0.41818
# Epoch 174/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7545 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00174: val_accuracy did not improve from 0.41818
# Epoch 175/500
# 143/143 [==============================] - 1s 4ms/step - loss: 5.6758 - accuracy: 0.5734 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00175: val_accuracy did not improve from 0.41818
# Epoch 176/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4767 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00176: val_accuracy did not improve from 0.41818
# Epoch 177/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4002 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00177: val_accuracy did not improve from 0.41818
# Epoch 178/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8514 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00178: val_accuracy did not improve from 0.41818
# Epoch 179/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2855 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00179: val_accuracy did not improve from 0.41818
# Epoch 180/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2824 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00180: val_accuracy did not improve from 0.41818
# Epoch 181/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6851 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00181: val_accuracy did not improve from 0.41818
# Epoch 182/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1467 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00182: val_accuracy did not improve from 0.41818
# Epoch 183/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5026 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00183: val_accuracy did not improve from 0.41818
# Epoch 184/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4879 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00184: val_accuracy did not improve from 0.41818
# Epoch 185/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8748 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00185: val_accuracy did not improve from 0.41818
# Epoch 186/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8411 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00186: val_accuracy did not improve from 0.41818
# Epoch 187/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6445 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00187: val_accuracy did not improve from 0.41818
# Epoch 188/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6846 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00188: val_accuracy did not improve from 0.41818
# Epoch 189/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7337 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00189: val_accuracy did not improve from 0.41818
# Epoch 190/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.4428 - accuracy: 0.4126 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00190: val_accuracy did not improve from 0.41818
# Epoch 191/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.2374 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00191: val_accuracy did not improve from 0.41818
# Epoch 192/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9180 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00192: val_accuracy did not improve from 0.41818
# Epoch 193/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.3437 - accuracy: 0.4196 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00193: val_accuracy did not improve from 0.41818
# Epoch 194/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.5474 - accuracy: 0.3986 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00194: val_accuracy did not improve from 0.41818
# Epoch 195/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7308 - accuracy: 0.5245 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00195: val_accuracy did not improve from 0.41818
# Epoch 196/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7921 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00196: val_accuracy did not improve from 0.41818
# Epoch 197/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2114 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00197: val_accuracy did not improve from 0.41818
# Epoch 198/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7434 - accuracy: 0.5245 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00198: val_accuracy did not improve from 0.41818
# Epoch 199/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4018 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00199: val_accuracy did not improve from 0.41818
# Epoch 200/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7133 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00200: val_accuracy did not improve from 0.41818
# Epoch 201/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5811 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00201: val_accuracy did not improve from 0.41818
# Epoch 202/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1547 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00202: val_accuracy did not improve from 0.41818
# Epoch 203/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6885 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00203: val_accuracy did not improve from 0.41818
# Epoch 204/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1514 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00204: val_accuracy did not improve from 0.41818
# Epoch 205/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0622 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00205: val_accuracy did not improve from 0.41818
# Epoch 206/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7604 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00206: val_accuracy did not improve from 0.41818
# Epoch 207/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5991 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00207: val_accuracy did not improve from 0.41818
# Epoch 208/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7132 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00208: val_accuracy did not improve from 0.41818
# Epoch 209/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7024 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00209: val_accuracy did not improve from 0.41818
# Epoch 210/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.1820 - accuracy: 0.5734 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00210: val_accuracy did not improve from 0.41818
# Epoch 211/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2628 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00211: val_accuracy did not improve from 0.41818
# Epoch 212/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1583 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00212: val_accuracy did not improve from 0.41818
# Epoch 213/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0169 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00213: val_accuracy did not improve from 0.41818
# Epoch 214/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2782 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00214: val_accuracy did not improve from 0.41818
# Epoch 215/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.4275 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00215: val_accuracy did not improve from 0.41818
# Epoch 216/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.1955 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00216: val_accuracy did not improve from 0.41818
# Epoch 217/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0465 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00217: val_accuracy did not improve from 0.41818
# Epoch 218/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5171 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00218: val_accuracy did not improve from 0.41818
# Epoch 219/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8571 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00219: val_accuracy did not improve from 0.41818
# Epoch 220/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0405 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00220: val_accuracy did not improve from 0.41818
# Epoch 221/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5912 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00221: val_accuracy did not improve from 0.41818
# Epoch 222/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1859 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00222: val_accuracy did not improve from 0.41818
# Epoch 223/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4761 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00223: val_accuracy did not improve from 0.41818
# Epoch 224/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5185 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00224: val_accuracy did not improve from 0.41818
# Epoch 225/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4867 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00225: val_accuracy did not improve from 0.41818
# Epoch 226/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2638 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00226: val_accuracy did not improve from 0.41818
# Epoch 227/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5061 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00227: val_accuracy did not improve from 0.41818
# Epoch 228/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0448 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00228: val_accuracy did not improve from 0.41818
# Epoch 229/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.8110 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00229: val_accuracy did not improve from 0.41818
# Epoch 230/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1213 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00230: val_accuracy did not improve from 0.41818
# Epoch 231/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0516 - accuracy: 0.4126 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00231: val_accuracy did not improve from 0.41818
# Epoch 232/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.4025 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00232: val_accuracy did not improve from 0.41818
# Epoch 233/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0641 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00233: val_accuracy did not improve from 0.41818
# Epoch 234/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8230 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00234: val_accuracy did not improve from 0.41818
# Epoch 235/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8135 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00235: val_accuracy did not improve from 0.41818
# Epoch 236/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4102 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00236: val_accuracy did not improve from 0.41818
# Epoch 237/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.3384 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00237: val_accuracy did not improve from 0.41818
# Epoch 238/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2716 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00238: val_accuracy did not improve from 0.41818
# Epoch 239/500
# ...
#
# Epoch 00421: val_accuracy did not improve from 0.41818
# Epoch 422/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8652 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00422: val_accuracy did not improve from 0.41818
# Epoch 423/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1778 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00423: val_accuracy did not improve from 0.41818
# Epoch 424/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5318 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00424: val_accuracy did not improve from 0.41818
# Epoch 425/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3969 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00425: val_accuracy did not improve from 0.41818
# Epoch 426/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7626 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00426: val_accuracy did not improve from 0.41818
# Epoch 427/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.3517 - accuracy: 0.3986 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00427: val_accuracy did not improve from 0.41818
# Epoch 428/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3844 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00428: val_accuracy did not improve from 0.41818
# Epoch 429/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4775 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00429: val_accuracy did not improve from 0.41818
# Epoch 430/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4780 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00430: val_accuracy did not improve from 0.41818
# Epoch 431/500
# 143/143 [==============================] - 1s 4ms/step - loss: 5.5600 - accuracy: 0.6014 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00431: val_accuracy did not improve from 0.41818
# Epoch 432/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1818 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00432: val_accuracy did not improve from 0.41818
# Epoch 433/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3790 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00433: val_accuracy did not improve from 0.41818
# Epoch 434/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.4651 - accuracy: 0.3916 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00434: val_accuracy did not improve from 0.41818
# Epoch 435/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4774 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00435: val_accuracy did not improve from 0.41818
# Epoch 436/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6237 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00436: val_accuracy did not improve from 0.41818
# Epoch 437/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5279 - accuracy: 0.5385 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00437: val_accuracy did not improve from 0.41818
# Epoch 438/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0418 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00438: val_accuracy did not improve from 0.41818
# Epoch 439/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1176 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00439: val_accuracy did not improve from 0.41818
# Epoch 440/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4749 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00440: val_accuracy did not improve from 0.41818
# Epoch 441/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.1302 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00441: val_accuracy did not improve from 0.41818
# Epoch 442/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7485 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00442: val_accuracy did not improve from 0.41818
# Epoch 443/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7247 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00443: val_accuracy did not improve from 0.41818
# Epoch 444/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9178 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00444: val_accuracy did not improve from 0.41818
# Epoch 445/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0134 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00445: val_accuracy did not improve from 0.41818
# Epoch 446/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1640 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00446: val_accuracy did not improve from 0.41818
# Epoch 447/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6416 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00447: val_accuracy did not improve from 0.41818
# Epoch 448/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2297 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00448: val_accuracy did not improve from 0.41818
# Epoch 449/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2168 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00449: val_accuracy did not improve from 0.41818
# Epoch 450/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3979 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00450: val_accuracy did not improve from 0.41818
# Epoch 451/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.4347 - accuracy: 0.4126 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00451: val_accuracy did not improve from 0.41818
# Epoch 452/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.4228 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00452: val_accuracy did not improve from 0.41818
# Epoch 453/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.3318 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00453: val_accuracy did not improve from 0.41818
# Epoch 454/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6118 - accuracy: 0.5455 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00454: val_accuracy did not improve from 0.41818
# Epoch 455/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6958 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00455: val_accuracy did not improve from 0.41818
# Epoch 456/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1564 - accuracy: 0.5245 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00456: val_accuracy did not improve from 0.41818
# Epoch 457/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9521 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00457: val_accuracy did not improve from 0.41818
# Epoch 458/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4649 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00458: val_accuracy did not improve from 0.41818
# Epoch 459/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0423 - accuracy: 0.4196 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00459: val_accuracy did not improve from 0.41818
# Epoch 460/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6402 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00460: val_accuracy did not improve from 0.41818
# Epoch 461/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6295 - accuracy: 0.5175 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00461: val_accuracy did not improve from 0.41818
# Epoch 462/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4886 - accuracy: 0.4685 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00462: val_accuracy did not improve from 0.41818
# Epoch 463/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5463 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00463: val_accuracy did not improve from 0.41818
# Epoch 464/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4762 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00464: val_accuracy did not improve from 0.41818
# Epoch 465/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.3947 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00465: val_accuracy did not improve from 0.41818
# Epoch 466/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4155 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00466: val_accuracy did not improve from 0.41818
# Epoch 467/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1679 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00467: val_accuracy did not improve from 0.41818
# Epoch 468/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.8157 - accuracy: 0.5245 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00468: val_accuracy did not improve from 0.41818
# Epoch 469/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7201 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00469: val_accuracy did not improve from 0.41818
# Epoch 470/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.4821 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00470: val_accuracy did not improve from 0.41818
# Epoch 471/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.0020 - accuracy: 0.5594 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00471: val_accuracy did not improve from 0.41818
# Epoch 472/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.2453 - accuracy: 0.4266 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00472: val_accuracy did not improve from 0.41818
# Epoch 473/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.9165 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00473: val_accuracy did not improve from 0.41818
# Epoch 474/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9181 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00474: val_accuracy did not improve from 0.41818
# Epoch 475/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6604 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00475: val_accuracy did not improve from 0.41818
# Epoch 476/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0823 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00476: val_accuracy did not improve from 0.41818
# Epoch 477/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5041 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00477: val_accuracy did not improve from 0.41818
# Epoch 478/500
# 143/143 [==============================] - 1s 4ms/step - loss: 9.2025 - accuracy: 0.3427 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00478: val_accuracy did not improve from 0.41818
# Epoch 479/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2493 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00479: val_accuracy did not improve from 0.41818
# Epoch 480/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.6548 - accuracy: 0.3916 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00480: val_accuracy did not improve from 0.41818
# Epoch 481/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6842 - accuracy: 0.4965 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00481: val_accuracy did not improve from 0.41818
# Epoch 482/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5970 - accuracy: 0.4615 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00482: val_accuracy did not improve from 0.41818
# Epoch 483/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.6501 - accuracy: 0.5245 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00483: val_accuracy did not improve from 0.41818
# Epoch 484/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1515 - accuracy: 0.5035 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00484: val_accuracy did not improve from 0.41818
# Epoch 485/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.2925 - accuracy: 0.4755 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00485: val_accuracy did not improve from 0.41818
# Epoch 486/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.5890 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00486: val_accuracy did not improve from 0.41818
# Epoch 487/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.7190 - accuracy: 0.4406 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00487: val_accuracy did not improve from 0.41818
# Epoch 488/500
# 143/143 [==============================] - 1s 4ms/step - loss: 5.7766 - accuracy: 0.5804 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00488: val_accuracy did not improve from 0.41818
# Epoch 489/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.5168 - accuracy: 0.5315 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00489: val_accuracy did not improve from 0.41818
# Epoch 490/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.7439 - accuracy: 0.5245 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00490: val_accuracy did not improve from 0.41818
# Epoch 491/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.0730 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00491: val_accuracy did not improve from 0.41818
# Epoch 492/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1587 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00492: val_accuracy did not improve from 0.41818
# Epoch 493/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9132 - accuracy: 0.4476 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00493: val_accuracy did not improve from 0.41818
# Epoch 494/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.9037 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00494: val_accuracy did not improve from 0.41818
# Epoch 495/500
# 143/143 [==============================] - 1s 4ms/step - loss: 6.2158 - accuracy: 0.5524 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00495: val_accuracy did not improve from 0.41818
# Epoch 496/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0134 - accuracy: 0.4336 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00496: val_accuracy did not improve from 0.41818
# Epoch 497/500
# 143/143 [==============================] - 1s 4ms/step - loss: 8.0147 - accuracy: 0.4545 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00497: val_accuracy did not improve from 0.41818
# Epoch 498/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1537 - accuracy: 0.4895 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00498: val_accuracy did not improve from 0.41818
# Epoch 499/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.1498 - accuracy: 0.5105 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00499: val_accuracy did not improve from 0.41818
# Epoch 500/500
# 143/143 [==============================] - 1s 4ms/step - loss: 7.6694 - accuracy: 0.4825 - val_loss: 8.9234 - val_accuracy: 0.4182
#
# Epoch 00500: val_accuracy did not improve from 0.41818

# %%
time = (toc-tic)/60
print("Total training time is: ", time)
# Out:
# Total training time is:  5.435103233333333

# %%
_, acc = model.evaluate(val_x, val_Y, verbose=0)
print('validation acc> %.3f' % (acc* 100.0),', bs:',batch_size,', epo:',epoch)
# Out:
# validation acc> 41.818 , bs: 16 , epo: 500

# %%
from keras.models import load_model
model_new = load_model(pathModelSave)

_train, acc_train = model_new.evaluate(train_x, train_Y, verbose=0)
print('training acc> %.3f' % (acc_train* 100.0),', bs:',batch_size,', epo:',epoch)

_val, acc_val = model_new.evaluate(val_x, val_Y, verbose=0)
print('val..... acc> %.3f' % (acc_val* 100.0),', bs:',batch_size,', epo:',epoch)

_test, acc_test = model_new.evaluate(test_x, test_Y, verbose=0)
print('testing. acc> %.3f' % (acc_test* 100.0),', bs:',batch_size,', epo:',epoch)
# Out:
# training acc> 41.958 , bs: 16 , epo: 500
# val..... acc> 41.818 , bs: 16 , epo: 500
# testing. acc> 43.478 , bs: 16 , epo: 500

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
Y_prediction = model_new.predict(test_x)
Y_pred_classes = []
for i in Y_prediction:
  if i[0] < 0.5:
    Y_pred_classes.append(0)
  else:
    Y_pred_classes.append(1)

Y_pred_classes = np.asarray(Y_pred_classes)
confusion_mtx = confusion_matrix(test_y, Y_pred_classes)

import seaborn as sns
plt.figure(figsize=(5,5))
sns.heatmap(confusion_mtx, annot=True, fmt="d");
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# author Manoj kaushik
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper left')
plt.show()

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='upper left')
plt.show()

# %%
# testing accuracies
import time
import os
import pandas as pd
import numpy as np
import sys
from keras.models import load_model
model = load_model(pathModelSave)

def predict_fun(filename, type, row):
  list = os.listdir(filename)
  list.sort()
  tic = time.clock()
  count_control = 0
  count = 0
  for name in list:
      count += 1
      file = os.path.join(filename, name)
      df = pd.read_csv(file, header = None, error_bad_lines = False)
      values = df.values[row - 1]
      data = []
      data.append(values.tolist())
      data = np.asarray(data)
      values = sequence.pad_sequences(data, maxlen = maxlen)
      p = model.predict(values)[0][0]
      if p < 0.5:
        count_control += 1
      #   print(count, '. ', name, ": Control predicted")
      # else :
      #   print(count, '. ', name, ": Epilipsy Pridicted")
  toc = time.clock()
  total_ele = len(list)
  print('total files of ' + str(type)+' are :', count, ' control predicted:', count_control, ' epilipsy predicted:', count - count_control, '| row',row)

# %%
# total files of control are : 93  control predicted: 91  epilipsy predicted: 2 | row 8
# total files of epilipsy are : 128  control predicted: 21  epilipsy predicted: 107 | row 8

# total files of control are : 46  control predicted: 15  epilipsy predicted: 31 | row 2
# total files of epilipsy are : 51  control predicted: 14  epilipsy predicted: 37 | row 2

# %%
# predict_fun('/content/drive/My Drive/datasets/EEGs_Nigeria_transposed/control/', 'control', 8)
# predict_fun('/content/drive/My Drive/datasets/EEGs_Nigeria_transposed/epilipsy/', 'epilipsy', 8)

# %%
# predict_fun('/content/drive/My Drive/datasets/EEGs_Guinea-Bissau_classified/control/', 'control', 2)
# predict_fun('/content/drive/My Drive/datasets/EEGs_Guinea-Bissau_classified/epilipsy/', 'epilipsy', 2)
